# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaktijagtap2406/Daily-programming-challenge/blob/main/heart_disease_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()  # upload kaggle.json
# Out:
#      <input type="file" id="files-43e9c310-3641-476c-9214-1987a5c80f32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43e9c310-3641-476c-9214-1987a5c80f32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d simhadrisadaram/mimic-cxr-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/simhadrisadaram/mimic-cxr-dataset
# License(s): unknown
# ^C

# %%
# !unzip mimic-cxr-dataset.zip
# Out:
# unzip:  cannot find or open mimic-cxr-dataset.zip, mimic-cxr-dataset.zip.zip or mimic-cxr-dataset.zip.ZIP.

# %%
mimic-cxr-dataset.zip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4015537858.py in <cell line: 0>()
# ----> 1 mimic-cxr-dataset.zip
#
# NameError: name 'mimic' is not defined

# %%
# !ls
# Out:
# kaggle.json  sample_data

# %%
# !kaggle datasets download -d simhadrisadaram/mimic-cxr-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/simhadrisadaram/mimic-cxr-dataset
# License(s): unknown
# ^C

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download \
  -d simhadrisadaram/mimic-cxr-dataset \
  -p /content/drive/MyDrive/mimic_cxr \
  --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/simhadrisadaram/mimic-cxr-dataset
# License(s): unknown
# ^C

# %%
import kagglehub
path = kagglehub.dataset_download("simhadrisadaram/mimic-cxr-dataset")
# Out:
# ...
# 100%|██████████| 16.5G/16.5G [02:24<00:00, 122MB/s]
# Extracting files...

# %%
# !ls
# Out:
# drive  kaggle.json  sample_data

# %%
# !find /content -maxdepth 3 -type d | head -50
# Out:
# /content
# /content/.config
# /content/.config/logs
# /content/.config/logs/2026.01.16
# /content/.config/configurations
# /content/drive
# /content/drive/.shortcut-targets-by-id
# /content/drive/MyDrive
# /content/drive/MyDrive/Classroom
# /content/drive/MyDrive/Certificates and marksheet
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/Resume
# /content/drive/.Trash-0
# /content/drive/.Trash-0/files
# /content/drive/.Trash-0/info
# /content/drive/.Encrypted
# /content/drive/.Encrypted/.shortcut-targets-by-id
# /content/drive/.Encrypted/MyDrive
# /content/sample_data

# %%
# !du -h /content | sort -h | tail -20
# Out:
# 4.0K	/content/drive/MyDrive/Classroom/FE ENGG.MATHS-I_24-25_SEM-I COMP A & B Div
# 4.0K	/content/drive/.shortcut-targets-by-id
# 4.0K	/content/drive/.Trash-0/files
# 4.0K	/content/drive/.Trash-0/info
# 8.0K	/content/.config/configurations
# 12K	/content/drive/.Trash-0
# 24K	/content/drive/.Encrypted/MyDrive/Classroom
# 40K	/content/drive/.Encrypted/MyDrive
# 48K	/content/drive/.Encrypted
# 52K	/content/drive/MyDrive/Colab Notebooks
# 88K	/content/.config/logs/2026.01.16
# 92K	/content/.config/logs
# 148K	/content/.config
# 180K	/content/drive/MyDrive/Resume
# 622K	/content/drive/MyDrive/Classroom
# 13M	/content/drive/MyDrive/Certificates and marksheet
# 26M	/content/drive
# 26M	/content/drive/MyDrive
# 55M	/content/sample_data
# 80M	/content

# %%
# !ls /content/.cache/kagglehub
# Out:
# ls: cannot access '/content/.cache/kagglehub': No such file or directory

# %%
# !du -h /content --max-depth=3 | sort -h | tail -20
# Out:
# 4.0K	/content/drive/.Encrypted/.shortcut-targets-by-id
# 4.0K	/content/drive/.shortcut-targets-by-id
# 4.0K	/content/drive/.Trash-0/files
# 4.0K	/content/drive/.Trash-0/info
# 8.0K	/content/.config/configurations
# 12K	/content/drive/.Trash-0
# 40K	/content/drive/.Encrypted/MyDrive
# 48K	/content/drive/.Encrypted
# 52K	/content/drive/MyDrive/Colab Notebooks
# 88K	/content/.config/logs/2026.01.16
# 92K	/content/.config/logs
# 148K	/content/.config
# 180K	/content/drive/MyDrive/Resume
# 622K	/content/drive/MyDrive/Classroom
# 13M	/content/drive/MyDrive/Certificates and marksheet
# 26M	/content/drive
# 26M	/content/drive/MyDrive
# 55M	/content/sample_data
# 80M	/content

# %%
# !ls /content/mimic-cxr-dataset
# Out:
# ls: cannot access '/content/mimic-cxr-dataset': No such file or directory

# %%
# !du -h /root/.cache --max-depth=4 | sort -h | tail -20
# Out:
# 36K	/root/.cache/matplotlib
# 56M	/root/.cache/node-gyp
# 56M	/root/.cache/node-gyp/20.19.0
# 56M	/root/.cache/node-gyp/20.19.0/include
# 56M	/root/.cache/node-gyp/20.19.0/include/node
# 18G	/root/.cache/kagglehub
# 18G	/root/.cache/kagglehub/datasets
# 18G	/root/.cache/kagglehub/datasets/simhadrisadaram
# 18G	/root/.cache/kagglehub/datasets/simhadrisadaram/mimic-cxr-dataset
# 19G	/root/.cache

# %%
# !find /root/.cache -type d -name "*mimic*" | head -20
# Out:
# /root/.cache/kagglehub/datasets/simhadrisadaram/mimic-cxr-dataset

# %%
# !ls PATH
# Out:
# ls: cannot access 'PATH': No such file or directory
